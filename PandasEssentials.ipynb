# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns=['A', 'B', 'C'], index=['x', 'y', 'z'])

# %%
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='str')

# %%
df.index.size
# Out:
# 3

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
result = pd.read_csv("data/results.csv")
result
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
result
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
result.sample(10, random_state=1)
# Out:
#           year    type                        discipline  \
# 288565  2020.0  Summer                            Boxing
# 57866   1972.0  Summer  Artistic Gymnastics (Gymnastics)
# 62957   1952.0  Summer  Artistic Gymnastics (Gymnastics)
# 269319  2012.0  Summer             Water Polo (Aquatics)
# 62254   1908.0  Summer  Artistic Gymnastics (Gymnastics)
# 269358  2016.0  Summer                         Athletics
# 75029   1996.0  Summer                          Handball
# 19642   1960.0  Summer   Equestrian Jumping (Equestrian)
# 165394  1920.0  Summer                         Athletics
# 59966   1984.0  Summer  Artistic Gymnastics (Gymnastics)
#
#                                          event                  as  \
# 288565                Flyweight, Men (Olympic)          Yoel Finol
# 57866          Floor Exercise, Women (Olympic)         Cathy Rigby
# 62957            Horizontal Bar, Men (Olympic)        Frank Turner
# ...

# %%
result.iloc[:, 1:3]
# Out:
#           type              discipline
# 0       Summer                  Tennis
# 1       Summer                  Tennis
# 2       Summer                  Tennis
# 3       Summer                  Tennis
# 4       Summer                  Tennis
# ...        ...                     ...
# 308403  Winter                    Luge
# 308404  Winter  Alpine Skiing (Skiing)
# 308405  Winter  Alpine Skiing (Skiing)
# 308406  Winter  Alpine Skiing (Skiing)
# 308407  Winter                     NaN
#
# [308408 rows x 2 columns]

# %%
result.loc[[0, 1, 5]] #index based
# Out:
#      year    type discipline                   event                     as  \
# 0  1912.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis  Doubles, Men (Olympic)  Jean-François Blanchy
# 5  1996.0  Summer     Tennis  Singles, Men (Olympic)         Arnaud Boetsch
#
#    athlete_id  noc            team  place   tied medal
# 0           1  FRA             NaN   17.0   True   NaN
# 1           1  FRA  Jean Montariol    NaN  False   NaN
# 5           2  FRA             NaN   17.0   True   NaN

# %%
result.loc[1:5, ["type", 'event', 'discipline']] #row column based
# Out:
#      type                     event discipline
# 1  Summer    Doubles, Men (Olympic)     Tennis
# 2  Summer    Singles, Men (Olympic)     Tennis
# 3  Summer  Doubles, Mixed (Olympic)     Tennis
# 4  Summer    Doubles, Men (Olympic)     Tennis
# 5  Summer    Singles, Men (Olympic)     Tennis

# %%
result.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
result.index = result['athlete_id']
result.head()
# Out:
#               year    type discipline                     event  \
# athlete_id
# 1           1912.0  Summer     Tennis    Singles, Men (Olympic)
# 1           1912.0  Summer     Tennis    Doubles, Men (Olympic)
# 1           1920.0  Summer     Tennis    Singles, Men (Olympic)
# 1           1920.0  Summer     Tennis  Doubles, Mixed (Olympic)
# 1           1920.0  Summer     Tennis    Doubles, Men (Olympic)
#
#                                as  athlete_id  noc             team  place  \
# athlete_id
# 1           Jean-François Blanchy           1  FRA              NaN   17.0
# 1           Jean-François Blanchy           1  FRA   Jean Montariol    NaN
# 1           Jean-François Blanchy           1  FRA              NaN   32.0
# 1           Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0
# 1           Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0
#
#              tied medal
# athlete_id
# 1            True   NaN
# 1           False   NaN
# ...

# %%
result.loc[3:7]
# Out:
#               year    type    discipline                     event  \
# athlete_id
# 3           1924.0  Summer        Tennis    Singles, Men (Olympic)
# 3           1924.0  Summer        Tennis  Doubles, Mixed (Olympic)
# 3           1924.0  Summer        Tennis    Doubles, Men (Olympic)
# 4           1920.0  Summer        Tennis    Singles, Men (Olympic)
# 4           1920.0  Summer        Tennis    Doubles, Men (Olympic)
# 4           1924.0  Summer        Tennis    Doubles, Men (Olympic)
# 5           1912.0  Summer        Tennis    Singles, Men (Olympic)
# 5           1912.0  Summer        Tennis  Doubles, Mixed (Olympic)
# 5           1912.0  Summer        Tennis    Doubles, Men (Olympic)
# 6           1992.0  Summer  Table Tennis    Singles, Men (Olympic)
# 6           1992.0  Summer  Table Tennis    Doubles, Men (Olympic)
# 7           1992.0  Summer  Table Tennis    Doubles, Men (Olympic)
# 7           1996.0  Summer  Table Tennis    Singles, Men (Olympic)
# ...

# %%
result.reset_index(inplace=True, drop=True)

# %%
result.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %% [markdown]
# __Accessing data__

# %%
result['year']
# Out:
# 0         1912.0
# 1         1912.0
# 2         1920.0
# 3         1920.0
# 4         1920.0
#            ...
# 308403    2022.0
# 308404    2022.0
# 308405    2022.0
# 308406    2022.0
# 308407    2022.0
# Name: year, Length: 308408, dtype: float64

# %%
result.year
# Out:
# 0         1912.0
# 1         1912.0
# 2         1920.0
# 3         1920.0
# 4         1920.0
#            ...
# 308403    2022.0
# 308404    2022.0
# 308405    2022.0
# 308406    2022.0
# 308407    2022.0
# Name: year, Length: 308408, dtype: float64

# %%
result.sort_values(['year', 'type'], ascending=[0, 0])#False, also 0 1 means true-false asc for column
# Out:
#           year    type               discipline  \
# 173195  2022.0  Winter  Speed Skating (Skating)
# 173196  2022.0  Winter  Speed Skating (Skating)
# 213793  2022.0  Winter   Alpine Skiing (Skiing)
# 213794  2022.0  Winter   Alpine Skiing (Skiing)
# 215139  2022.0  Winter     Ski Jumping (Skiing)
# ...        ...     ...                      ...
# 203177     NaN     NaN                  Fencing
# 203178     NaN     NaN                  Fencing
# 217586     NaN     NaN      Football (Football)
# 217587     NaN     NaN      Football (Football)
# 271490     NaN     NaN        Diving (Aquatics)
#
#                                          event                    as  \
# 173195           3,000 metres, Women (Olympic)     Claudia Pechstein
# 173196             Mass Start, Women (Olympic)     Claudia Pechstein
# 213793                Super G, Women (Olympic)        Sarah Schleper
# 213794           Giant Slalom, Women (Olympic)        Sarah Schleper
# ...

# %%
# for index, row in result.iterrows():
#     print(index)
#     print(row)
#     print("\n\n")

# %%
result.tail()
# Out:
#           year    type              discipline                          event  \
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
#                           as  athlete_id  noc    team  place   tied medal
# 308403         Marián Skupek      148983  SVK     NaN   26.0  False   NaN
# 308404         Elsa Fermbäck      148984  SWE     NaN   28.0  False   NaN
# 308405         Hilma Lövblom      148985  SWE  Sweden   13.0  False   NaN
# 308406         Hilma Lövblom      148985  SWE     NaN    NaN  False   NaN
# 308407  Charlotta Säfvenberg      148986  NaN     NaN   24.0  False   NaN

# %%
result.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  str
#  2   discipline  308407 non-null  str
#  3   event       308408 non-null  str
#  4   as          308408 non-null  str
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  str
#  7   team        121714 non-null  str
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   str
# dtypes: bool(1), float64(2), int64(1), str(7)
# memory usage: 23.8 MB

# %%
result.loc[result['year'] > 2020]
# Out:
#           year    type               discipline  \
# 173195  2022.0  Winter  Speed Skating (Skating)
# 173196  2022.0  Winter  Speed Skating (Skating)
# 213793  2022.0  Winter   Alpine Skiing (Skiing)
# 213794  2022.0  Winter   Alpine Skiing (Skiing)
# 215139  2022.0  Winter     Ski Jumping (Skiing)
# ...        ...     ...                      ...
# 308403  2022.0  Winter                     Luge
# 308404  2022.0  Winter   Alpine Skiing (Skiing)
# 308405  2022.0  Winter   Alpine Skiing (Skiing)
# 308406  2022.0  Winter   Alpine Skiing (Skiing)
# 308407  2022.0  Winter                      NaN
#
#                                          event                    as  \
# 173195           3,000 metres, Women (Olympic)     Claudia Pechstein
# 173196             Mass Start, Women (Olympic)     Claudia Pechstein
# 213793                Super G, Women (Olympic)        Sarah Schleper
# 213794           Giant Slalom, Women (Olympic)        Sarah Schleper
# ...

# %%
result[result['year'] > 2020]
# Out:
#           year    type               discipline  \
# 173195  2022.0  Winter  Speed Skating (Skating)
# 173196  2022.0  Winter  Speed Skating (Skating)
# 213793  2022.0  Winter   Alpine Skiing (Skiing)
# 213794  2022.0  Winter   Alpine Skiing (Skiing)
# 215139  2022.0  Winter     Ski Jumping (Skiing)
# ...        ...     ...                      ...
# 308403  2022.0  Winter                     Luge
# 308404  2022.0  Winter   Alpine Skiing (Skiing)
# 308405  2022.0  Winter   Alpine Skiing (Skiing)
# 308406  2022.0  Winter   Alpine Skiing (Skiing)
# 308407  2022.0  Winter                      NaN
#
#                                          event                    as  \
# 173195           3,000 metres, Women (Olympic)     Claudia Pechstein
# 173196             Mass Start, Women (Olympic)     Claudia Pechstein
# 213793                Super G, Women (Olympic)        Sarah Schleper
# 213794           Giant Slalom, Women (Olympic)        Sarah Schleper
# ...

# %%
result[result['year'] > 2020][['year', 'type']]
# Out:
#           year    type
# 173195  2022.0  Winter
# 173196  2022.0  Winter
# 213793  2022.0  Winter
# 213794  2022.0  Winter
# 215139  2022.0  Winter
# ...        ...     ...
# 308403  2022.0  Winter
# 308404  2022.0  Winter
# 308405  2022.0  Winter
# 308406  2022.0  Winter
# 308407  2022.0  Winter
#
# [4744 rows x 2 columns]

# %%
result[(result['year'] > 2020) & (result['noc'] == 'GER')][['year', 'type', 'noc']]
# Out:
#           year    type  noc
# 173195  2022.0  Winter  GER
# 173196  2022.0  Winter  GER
# 254675  2022.0  Winter  GER
# 254676  2022.0  Winter  GER
# 257150  2022.0  Winter  GER
# ...        ...     ...  ...
# 307465  2022.0  Winter  GER
# 307466  2022.0  Winter  GER
# 307467  2022.0  Winter  GER
# 307468  2022.0  Winter  GER
# 307469  2022.0  Winter  GER
#
# [257 rows x 3 columns]

# %%
result[result['discipline'].str.contains("alpine|ski", case=False)]
# Out:
#           year    type                     discipline  \
# 29420   1924.0  Winter  Cross Country Skiing (Skiing)
# 29421   1924.0  Winter  Cross Country Skiing (Skiing)
# 74584   1936.0  Winter         Alpine Skiing (Skiing)
# 74585   1936.0  Winter         Alpine Skiing (Skiing)
# 74586   1936.0  Winter         Alpine Skiing (Skiing)
# ...        ...     ...                            ...
# 308385  2022.0  Winter  Cross Country Skiing (Skiing)
# 308386  2022.0  Winter  Cross Country Skiing (Skiing)
# 308404  2022.0  Winter         Alpine Skiing (Skiing)
# 308405  2022.0  Winter         Alpine Skiing (Skiing)
# 308406  2022.0  Winter         Alpine Skiing (Skiing)
#
#                                          event               as  athlete_id  \
# 29420             18 kilometres, Men (Olympic)    Roberts Plūme       16155
# 29421             50 kilometres, Men (Olympic)    Roberts Plūme       16155
# 74584                  Combined, Men (Olympic)  Willi Zacharias       32613
# ...

# %%
result[(result['noc'].isin(['USA', "GER", 'FRA'])) & (result['event'].str.lower().str.startswith("singles"))]
# Out:
#           year    type                discipline                     event  \
# 0       1912.0  Summer                    Tennis    Singles, Men (Olympic)
# 2       1920.0  Summer                    Tennis    Singles, Men (Olympic)
# 5       1996.0  Summer                    Tennis    Singles, Men (Olympic)
# 7       1924.0  Summer                    Tennis    Singles, Men (Olympic)
# 10      1920.0  Summer                    Tennis    Singles, Men (Olympic)
# ...        ...     ...                       ...                       ...
# 306105  2020.0  Summer              Table Tennis    Singles, Men (Olympic)
# 307296  2022.0  Winter  Figure Skating (Skating)    Singles, Men (Olympic)
# 307441  2022.0  Winter                      Luge  Singles, Women (Olympic)
# 307442  2022.0  Winter                      Luge  Singles, Women (Olympic)
# 307443  2022.0  Winter                      Luge    Singles, Men (Olympic)
#
# ...

# %% [markdown]
# __Modify dataframe__

# %%
coffee = pd.read_csv('data/coffee.csv')
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['price'] = 4.99

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          15   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
coffee['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          15   4.99       5.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee.drop(0, inplace=True)

# %%
coffee.drop(columns=['price'], inplace=True)

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 1     Monday       Latte          15       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99
# 5  Wednesday       Latte          25       5.99

# %%
coffee_new = coffee.copy() #in case if we want to get same dataframe because in other way it will point to the same memory which means if we modify first dataframe second will be also affected

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price  revenue
# 1     Monday       Latte          15       5.99    89.85
# 2    Tuesday    Espresso          30       3.99   119.70
# 3    Tuesday       Latte          20       5.99   119.80
# 4  Wednesday    Espresso          35       3.99   139.65
# 5  Wednesday       Latte          25       5.99   149.75

# %%
coffee.rename(columns={'new_price': 'price'}, inplace=True)

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 1     Monday       Latte          15   5.99    89.85
# 2    Tuesday    Espresso          30   3.99   119.70
# 3    Tuesday       Latte          20   5.99   119.80
# 4  Wednesday    Espresso          35   3.99   139.65
# 5  Wednesday       Latte          25   5.99   149.75

# %%
result_new = pd.read_csv('data/results.csv')
result_new
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
print(result_new.head(1))
# Out:
#      year    type discipline                   event                     as  \
# 0  1912.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc team  place  tied medal
# 0           1  FRA  NaN   17.0  True   NaN

# %%
result_new['first_name'] = result_new['as'].str.split(" ").str[0]

# %%
result_new['first_name'].head()
# Out:
# 0    Jean-François
# 1    Jean-François
# 2    Jean-François
# 3    Jean-François
# 4    Jean-François
# Name: first_name, dtype: object

# %%
#we can convert object/string date into helpful type datetime using pd.to_datetime()

# %% [markdown]
# __Handling null values__

# %%
coffee.loc[[1, 2], 'Units Sold'] = np.nan

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# price          0
# revenue        0
# dtype: int64

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 1     Monday       Latte         NaN   5.99    89.85
# 2    Tuesday    Espresso         NaN   3.99   119.70
# 3    Tuesday       Latte        20.0   5.99   119.80
# 4  Wednesday    Espresso        35.0   3.99   139.65
# 5  Wednesday       Latte        25.0   5.99   149.75

# %%
coffee = coffee.fillna(coffee['Units Sold'].median())
#todo: also can do dropna(subset=[column name], inplace=bool) but be careful

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
#        Day Coffee Type  Units Sold  price  revenue
# 1   Monday       Latte         NaN   5.99    89.85
# 2  Tuesday    Espresso         NaN   3.99   119.70

# %%
coffee[coffee.isna().any(axis=1)]
# Out:
#        Day Coffee Type  Units Sold  price  revenue
# 1   Monday       Latte         NaN   5.99    89.85
# 2  Tuesday    Espresso         NaN   3.99   119.70

# %%
result['noc'].value_counts()
# Out:
# noc
# USA    21353
# FRA    14276
# GBR    13170
# ITA    12129
# CAN    11455
#        ...
# YAR       12
# TUV        9
# YMD        5
# SSD        5
# NBO        3
# Name: count, Length: 230, dtype: int64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    42.0
# Latte       30.0
# Name: Units Sold, dtype: float64
