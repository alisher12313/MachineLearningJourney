# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **K Nearest Neighbor**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will learn about and practice the K Nearest Neighbor (KNN) model. KNN is a straightforward but very effective model that can be used for both classification and regression tasks. If the feature space is not very large, KNN can be a high-interpretable model because you can explain and understand how a prediction is made by looking at its nearest neighbors.

# %% [markdown]
# We will be using a tumor sample dataset containing lab test results about tumor samples. The objective is to classify whether a tumor is malicious (cancer) or benign. As such, it is a typical binary classification task.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# * Train KNN models with different neighbor hyper-parameters
# * Evaluate KNN models on classification tasks
# * Tune the number of neighbors and find the optimized one for a specific task

# %% [markdown]
# ----

# %% [markdown]
# First, let's install `seaborn` for visualization tasks and import required libraries for this lab.

# %%
# All Libraries required for this lab are listed below. 
# !mamba install -qy pandas==1.3.3 numpy==1.21.2 ipywidgets==7.4.2 scipy==7.4.2 tqdm==4.62.3 matplotlib==3.5.0 seaborn==0.9.0
# Note: If your environment doesn't support "!mamba install", use "!pip install".

# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (2.5.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from seaborn) (2.5.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from scikit-learn) (2.5.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\user\desktop\mllibraries\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
# Evaluation metrics related methods
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix, precision_recall_fscore_support, precision_score, recall_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Define a random seed to reproduce any random process
rs = 123

# %%
# Ignore any deprecation warnings
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Load and explore the tumor sample dataset

# %% [markdown]
# We first load the dataset `tumor.csv` as a Pandas dataframe:

# %%
# Read datast in csv format
dataset_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML241EN-SkillsNetwork/labs/datasets/tumor.csv"
tumor_df = pd.read_csv(dataset_url)

# %% [markdown]
# Then, let's quickly take a look at the head of the dataframe.

# %%
tumor_df.head()
# Out:
#    Clump  UnifSize  UnifShape  MargAdh  SingEpiSize  BareNuc  BlandChrom  \
# 0      5         1          1        1            2        1           3
# 1      5         4          4        5            7       10           3
# 2      3         1          1        1            2        2           3
# 3      6         8          8        1            3        4           3
# 4      4         1          1        3            2        1           3
#
#    NormNucl  Mit  Class
# 0         1    1      0
# 1         2    1      0
# 2         1    1      0
# 3         7    1      0
# 4         1    1      0

# %% [markdown]
# And, display its columns.

# %%
tumor_df.columns
# Out:
# Index(['Clump', 'UnifSize', 'UnifShape', 'MargAdh', 'SingEpiSize', 'BareNuc',
#        'BlandChrom', 'NormNucl', 'Mit', 'Class'],
#       dtype='str')

# %% [markdown]
# Each observation in this dataset contains lab test results about a tumor sample, such as clump or shapes. Based on these lab test results or features, we want to build a classification model to predict if this tumor sample is malicious (cancer) or benign. The target variable `y` is specified in the `Class` column.

# %% [markdown]
# Then, let's split the dataset into input `X` and output `y`:

# %%
X = tumor_df.iloc[:, :-1]
y = tumor_df.iloc[:, -1:]

# %% [markdown]
# And, we first check the statistics summary of features in `X`:

# %%
X.describe()
# Out:
#             Clump    UnifSize   UnifShape     MargAdh  SingEpiSize  \
# count  683.000000  683.000000  683.000000  683.000000   683.000000
# mean     4.442167    3.150805    3.215227    2.830161     3.234261
# std      2.820761    3.065145    2.988581    2.864562     2.223085
# min      1.000000    1.000000    1.000000    1.000000     1.000000
# 25%      2.000000    1.000000    1.000000    1.000000     2.000000
# 50%      4.000000    1.000000    1.000000    1.000000     2.000000
# 75%      6.000000    5.000000    5.000000    4.000000     4.000000
# max     10.000000   10.000000   10.000000   10.000000    10.000000
#
#           BareNuc  BlandChrom    NormNucl         Mit
# count  683.000000  683.000000  683.000000  683.000000
# mean     3.544656    3.445095    2.869693    1.603221
# std      3.643857    2.449697    3.052666    1.732674
# min      1.000000    1.000000    1.000000    1.000000
# 25%      1.000000    2.000000    1.000000    1.000000
# 50%      1.000000    3.000000    1.000000    1.000000
# 75%      6.000000    5.000000    4.000000    1.000000
# max     10.000000   10.000000   10.000000   10.000000

# %% [markdown]
# As we can see from the above cell output, all features are numeric and ranged between 1 to 10. This is very convenient as we do not need to scale the feature values as they are already in the same range.

# %% [markdown]
# Next, let's check the class distribution of output `y`:

# %%
y.value_counts(normalize=True)
# Out:
# Class
# 0        0.650073
# 1        0.349927
# Name: proportion, dtype: float64

# %%
y.value_counts().plot.bar(color=['green', 'red'])
# Out:
# <Axes: xlabel='Class'>

# %% [markdown]
# We have about 65% benign tumors (`Class = 0`) and 35% cancerous tumors (`Class = 1`), which is not a very imbalanced class distribution.

# %% [markdown]
# ## Split training and testing datasets

# %%
# Split 80% as training dataset
# and 20% as testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state = rs)

# %% [markdown]
# ## Train and evaluate a KNN classifier with the number of neighbors set to 2

# %% [markdown]
# Training a KNN classifier is very similar to training other classifiers in `sklearn`, we first need to define a `KNeighborsClassifier` object. Here we use `n_neighbors=2` argument to specify how many neighbors will be used for prediction, and we keep other arguments to be their default values.

# %%
# Define a KNN classifier with `n_neighbors=2`
knn_model = KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# Then we can train the model with `X_train` and `y_train`, and we use ravel() method to convert the data frame `y_train` to a vector.

# %%
knn_model.fit(X_train, y_train.values.ravel())
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# And, we can make predictions on the `X_test` dataframe.

# %%
preds = knn_model.predict(X_test)

# %% [markdown]
# To evaluate the KNN classifier, we provide a pre-defined method to return the commonly used evaluation metrics such as accuracy, recall, precision, f1score, and so on, based on the true classes in the 'y_test' and model predictions.

# %%
def evaluate_metrics(yt, yp):
    results_pos = {}
    results_pos['accuracy'] = accuracy_score(yt, yp)
    precision, recall, f_beta, _ = precision_recall_fscore_support(yt, yp, average='binary')
    results_pos['recall'] = recall
    results_pos['precision'] = precision
    results_pos['f1score'] = f_beta
    return results_pos

# %%
evaluate_metrics(y_test, preds)
# Out:
# {'accuracy': 0.9416058394160584,
#  'recall': 0.875,
#  'precision': 0.9545454545454546,
#  'f1score': 0.9130434782608695}

# %% [markdown]
# We can see that there is a great classification performance on the tumor sample dataset. This means the KNN model can effectively recognize cancerous tumors.
# Next, it's your turn to try a different number of neighbors to see if we could get even better performance.

# %% [markdown]
# ## Coding exercise: Train and evaluate a KNN classifier with number of neighbors set to 5

# %% [markdown]
# First, define a KNN classifier with KNeighborsClassifier class:

# %%
# Type your code here
knn2 = KNeighborsClassifier(n_neighbors=5)

# %% [markdown]
# Then train the model with `X_train` and `y_train`:

# %%
# Type your code here
knn2.fit(X_train, y_train)
# Out:
# C:\Users\user\Desktop\MlLibraries\.venv\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %% [markdown]
# And, make predictions on `X_test` dataframe:

# %%
evaluate_metrics(y_test, knn2.predict(X_test))
# Out:
# {'accuracy': 0.9781021897810219,
#  'recall': 0.9791666666666666,
#  'precision': 0.9591836734693877,
#  'f1score': 0.9690721649484536}

# %% [markdown]
# |At last, you can evaluate your KNN model with provided `evaluate_metrics()` method.

# %% [markdown]
# <details><summary>Click here for a sample solution</summary>
#
# ```python
# model = KNeighborsClassifier(n_neighbors=5)
# model.fit(X_train, y_train.values.ravel())
# preds = model.predict(X_test)
# evaluate_metrics(y_test, preds)
# ```
#
# </details>

# %% [markdown]
# ## Tune the number of neighbors to find the optmized one

# %% [markdown]
# OK, you may wonder which `n_neighbors` argument may give you the best classification performance. We can try different `n_neighbors` (the K value) and check which `K` gives the best classification performance.

# %% [markdown]
# Here we could try K from 1 to 50, and store the aggregated `f1score` for each k into a list.

# %%
# Try K from 1 to 50
max_k = 50
# Create an empty list to store f1score for each k
f1_scores = []

# %% [markdown]
# Then we will train 50 KNN classifiers with K ranged from 1 to 50.

# %%
for k in range(1, max_k + 1):
    # Create a KNN classifier
    knn = KNeighborsClassifier(n_neighbors=k)
    # Train the classifier
    knn = knn.fit(X_train, y_train.values.ravel())
    preds = knn.predict(X_test)
    # Evaluate the classifier with f1score
    f1 = f1_score(preds, y_test)
    f1_scores.append((k, round(f1_score(y_test, preds), 4)))
# Convert the f1score list to a dataframe
f1_results = pd.DataFrame(f1_scores, columns=['K', 'F1 Score'])
f1_results.set_index('K')
# Out:
#     F1 Score
# K
# 1     0.9485
# 2     0.9130
# 3     0.9485
# 4     0.9583
# 5     0.9691
# 6     0.9583
# 7     0.9583
# 8     0.9474
# 9     0.9474
# 10    0.9474
# 11    0.9474
# 12    0.9474
# 13    0.9474
# 14    0.9474
# 15    0.9583
# 16    0.9583
# 17    0.9583
# 18    0.9583
# 19    0.9583
# 20    0.9583
# 21    0.9583
# 22    0.9583
# 23    0.9583
# 24    0.9583
# 25    0.9583
# 26    0.9583
# 27    0.9583
# 28    0.9474
# 29    0.9474
# 30    0.9474
# 31    0.9474
# 32    0.9474
# 33    0.9474
# 34    0.9362
# 35    0.9362
# 36    0.9362
# 37    0.9362
# 38    0.9362
# 39    0.9362
# 40    0.9362
# 41    0.9362
# 42    0.9362
# 43    0.9362
# 44    0.9362
# 45    0.9362
# 46    0.9362
# 47    0.9362
# 48    0.9362
# 49    0.9362
# 50    0.9362

# %% [markdown]
# This is a long list and different to analysis, so let's visualize the list using a linechart.

# %%
# Plot F1 results
ax = f1_results.plot(figsize=(12, 12))
ax.set(xlabel='Num of Neighbors', ylabel='F1 Score')
ax.set_xticks(range(1, max_k, 2));
plt.ylim((0.85, 1))
plt.title('KNN F1 Score')
# Out:
# Text(0.5, 1.0, 'KNN F1 Score')

# %% [markdown]
# As we can see from the F1 score linechart, the best `K` value is 5 with about `0.9691` f1score.

# %% [markdown]
# ## Next steps

# %% [markdown]
# Great! Now you have learned about and applied the KNN model to solve a real-world tumor type classification problem. You also tuned the KNN to find the best K value. Later, you will continue learning other popular classification models with different structures, assumptions, cost functions, and application scenarios.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo](https://www.linkedin.com/in/yan-luo-96288783/)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# <!--## Change Log--!>

# %% [markdown]
# <!--|Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2021-11-9|1.0|Yan|Created the initial version|
# |2022-3-29|1.1|Steve Hord|QA Pass|
# --!>

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
